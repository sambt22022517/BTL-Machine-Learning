# %%
import pandas as pd
import numpy as np
import seaborn as sbn

# %%
df = pd.read_csv('Cleaned_Data.csv')
df
# Out:
#        Unnamed: 0                                               Name
# 0               0                                    The Dark Knight  \
# 1               1      The Lord of the Rings: The Return of the King
# 2               2                             Dr. Babasaheb Ambedkar
# 3               3  The Lord of the Rings: The Fellowship of the Ring
# 4               4              The Lord of the Rings: The Two Towers
# ...           ...                                                ...
# 23773       24213                    The Lives of Mount Druitt Youth
# 23774       24214                                               Hich
# 23775       24215                            Kummeli Alivuokralainen
# 23776       24216                                   Någon Annanstans
# 23777       24217                                          Chambaili
#
#       Certificate                                             Poster
# 0           PG-13  https://m.media-amazon.com/images/M/MV5BMTMxNT...  \
# 1           PG-13  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 2         Unrated  https://m.media-amazon.com/images/M/MV5BNGNjZD...
# 3           PG-13  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 4           PG-13  https://m.media-amazon.com/images/M/MV5BZGMxZT...
# ...           ...                                                ...
# 23773     Unrated  https://m.media-amazon.com/images/M/MV5BMTI4MT...
# 23774     Unrated  https://m.media-amazon.com/images/M/MV5BYTY0Y2...
# 23775     Unrated  https://m.media-amazon.com/images/M/MV5BODI2MD...
# 23776     Unrated  https://m.media-amazon.com/images/M/MV5BMjA0Nz...
# 23777     Unrated  https://m.media-amazon.com/images/M/MV5BMTYxND...
#
#                           Genre           Director
# 0          Action, Crime, Drama  Christopher Nolan  \
# 1      Action, Adventure, Drama      Peter Jackson
# 2            Biography, History       Jabbar Patel
# 3      Action, Adventure, Drama      Peter Jackson
# 4      Action, Adventure, Drama      Peter Jackson
# ...                         ...                ...
# 23773        Documentary, Drama          Saad Adam
# 23774             Comedy, Drama   Abdolreza Kahani
# 23775                    Comedy     Matti Grönberg
# 23776            Drama, Romance        Hiwa Abbasi
# 23777    Crime, Drama, Thriller     Ismail Jillani
#
#                                                   Writer
# 0      Jonathan Nolan, Christopher Nolan, David S. Goyer  \
# 1            J.R.R. Tolkien, Fran Walsh, Philippa Boyens
# 2             Daya Pawar, Arun Sadhu, Sooni Taraporevala
# 3            J.R.R. Tolkien, Fran Walsh, Philippa Boyens
# 4            J.R.R. Tolkien, Fran Walsh, Philippa Boyens
# ...                                                  ...
# 23773                                                NaN
# 23774                   Abdolreza Kahani, Hossein Mahkam
# 23775      Timo Kahilainen, Heikki Vihinen, Anttu Harlin
# 23776                                        Hiwa Abbasi
# 23777                                      Shahzad Nawaz
#
#                                                    Stars
# 0      Christian Bale, Heath Ledger, Aaron Eckhart, M...  \
# 1      Elijah Wood, Viggo Mortensen, Ian McKellen, Or...
# 2      Mammootty, Sonali Kulkarni, Mohan Gokhale, Mri...
# 3      Elijah Wood, Ian McKellen, Orlando Bloom, Sean...
# 4      Elijah Wood, Ian McKellen, Viggo Mortensen, Or...
# ...                                                  ...
# 23773                 Drew Pearson, Saad Adam, Evan Adam
# 23774   Ahmad Mehranfar, Mehran Ahmadi, Nayereh Farahani
# 23775  Mikko Kivinen, Heikki Silvennoinen, Timo Kahil...
# 23776      Ruth Anianson, Arefeh Behbakht, Lina Burström
# 23777        Khalid Ahmed, Shafqat Cheema, Ehteshamuddin
#
#                                                Storyline
# 0      When the menace known as the Joker wreaks havo...
# 1      Gandalf and Aragorn lead the World of Men agai...
# 2      Biopic of B. R. Ambedkar, known mainly for his...
# 3      A meek Hobbit from the Shire and eight compani...
# 4      While Frodo and Sam edge closer to Mordor with...
# ...                                                  ...
# 23773  Come with Saad as he visits Mount Druitt &amp;...
# 23774  A man, who has some kind of a disease and eats...
# 23775  A farce about blackmailing, a kidney transplan...
# 23776  Said, the main character in the film Another P...
# 23777  A group of friends are led by circumstances to...
#
# [23778 rows x 9 columns]

# %%
import pandas as pd
import re
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stopwords_list = stopwords.words('english')

stopwords_list
stopwords_list.append(" ")
stopwords_list.append("")

# Define a function to split text into words and remove specified words
def split_into_words_and_remove_stopwords(text, stopwords):
    # Split text using various separators (space, period, comma)
    words = re.split(r'\s+|[,\.:!?"&]', text)
    # Remove specified stopwords from the list
    words = [word.lower() for word in words if word.lower() not in stopwords]
    return words


# Apply the function to the "storyline" column
df['Storyline'] = df['Storyline'].apply(lambda x: split_into_words_and_remove_stopwords(x, stopwords_list))
df['Genre'] = df['Genre'].apply(lambda x: split_into_words_and_remove_stopwords(x, stopwords_list))

# Display the DataFrame
df['Storyline']
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kingk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0        [menace, known, joker, wreaks, havoc, chaos, p...
# 1        [gandalf, aragorn, lead, world, men, sauron's,...
# 2        [biopic, b, r, ambedkar, known, mainly, contri...
# 3        [meek, hobbit, shire, eight, companions, set, ...
# 4        [frodo, sam, edge, closer, mordor, help, shift...
#                                ...
# 23773    [come, saad, visits, mount, druitt, amp;, inte...
# 23774    [man, kind, disease, eats, lot, enters, poor, ...
# 23775    [farce, blackmailing, kidney, transplant, oper...
# 23776    [said, main, character, film, another, place, ...
# 23777    [group, friends, led, circumstances, find, cro...
# Name: Storyline, Length: 23778, dtype: object

# %%
# df['Genre'] = df['Genre'].apply(lambda x: x.split(','))
# df['Genre'] = df['Genre'].apply(lambda x: split_into_words_and_remove_stopwords(x, stopwords_list))
all_genre = [genre for subgenre in df["Genre"] for genre in subgenre]
all_genre = list(set(all_genre))
all_genre
# df['Genre']
# Out:
# ['documentary',
#  'biography',
#  'mystery',
#  'history',
#  'crime',
#  'sci-fi',
#  'fantasy',
#  'music',
#  'drama',
#  'comedy',
#  'sport',
#  'news',
#  'western',
#  'action',
#  'horror',
#  'adventure',
#  'war',
#  'musical',
#  'romance',
#  'thriller',
#  'family',
#  'animation']

# %%
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X = [' '.join(row) for row in df['Storyline'].values]
for genre in all_genre:
    y = [genre in value for value in df['Genre'].values]

    # X là tập dữ liệu đặc trưng, y là nhãn
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Sử dụng TF-IDF để biểu diễn văn bản
    tfidf_vectorizer = TfidfVectorizer()
    X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
    X_test_tfidf = tfidf_vectorizer.transform(X_test)

    # Huấn luyện mô hình SVM
    svm_model = SVC(kernel='linear')
    svm_model.fit(X_train_tfidf, y_train)

    # Dự đoán trên tập kiểm tra
    y_pred = svm_model.predict(X_test_tfidf)

    # Đánh giá mô hình
    accuracy = accuracy_score(y_test, y_pred)
    print(genre + ": " + str(accuracy))
# Out:
# documentary: 0.9589290720493412
# biography: 0.9421082141855901
# mystery: 0.9105691056910569
# history: 0.9597701149425287
# crime: 0.8745444350995234
# sci-fi: 0.9582282029716849
# fantasy: 0.9538828146902159
# music: 0.9758901037286235
# drama: 0.6777403980936361
# comedy: 0.7465657415194842
# sport: 0.9802354920100925
# news: 0.9987384356602187
# western: 0.9967760022427811
# action: 0.8544995794785534
# horror: 0.9108494533221194
# adventure: 0.9060835435940566
# war: 0.9834594897673115
# musical: 0.9904681805438744
# romance: 0.8622091393327727
# thriller: 0.8287075974208018
# family: 0.9620128959910289
# animation: 0.9600504625735913
