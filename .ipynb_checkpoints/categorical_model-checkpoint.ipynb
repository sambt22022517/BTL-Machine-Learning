# %%
import pandas as pd
import numpy as np
import seaborn as sbn

# %%
df = pd.read_csv('Cleaned_Data.csv').head(20000)
test = pd.read_csv('Cleaned_Data.csv').tail(3778)
test
# Out:
#                                   Name Certificate
# 20000                   Family Weekend           R  \
# 20001             Nothing Left to Fear           R
# 20002                          Trishna           R
# 20003                  American Violet       PG-13
# 20004              Some Velvet Morning     Unrated
# ...                                ...         ...
# 23773  The Lives of Mount Druitt Youth     Unrated
# 23774                             Hich     Unrated
# 23775          Kummeli Alivuokralainen     Unrated
# 23776                 Någon Annanstans     Unrated
# 23777                        Chambaili     Unrated
#
#                                                   Poster
# 20000  https://m.media-amazon.com/images/M/MV5BMTg2MT...  \
# 20001  https://m.media-amazon.com/images/M/MV5BMTU3Nj...
# 20002  https://m.media-amazon.com/images/M/MV5BMTkxMT...
# 20003  https://m.media-amazon.com/images/M/MV5BMTYwNj...
# 20004  https://m.media-amazon.com/images/M/MV5BNTgxMz...
# ...                                                  ...
# 23773  https://m.media-amazon.com/images/M/MV5BMTI4MT...
# 23774  https://m.media-amazon.com/images/M/MV5BYTY0Y2...
# 23775  https://m.media-amazon.com/images/M/MV5BODI2MD...
# 23776  https://m.media-amazon.com/images/M/MV5BMjA0Nz...
# 23777  https://m.media-amazon.com/images/M/MV5BMTYxND...
#
#                         Genre              Director
# 20000           Comedy, Drama         Benjamin Epps  \
# 20001                  Horror  Anthony Leonardi III
# 20002                   Drama  Michael Winterbottom
# 20003                   Drama            Tim Disney
# 20004                   Drama           Neil LaBute
# ...                       ...                   ...
# 23773      Documentary, Drama             Saad Adam
# 23774           Comedy, Drama      Abdolreza Kahani
# 23775                  Comedy        Matti Grönberg
# 23776          Drama, Romance           Hiwa Abbasi
# 23777  Crime, Drama, Thriller        Ismail Jillani
#
#                                               Writer
# 20000                                 Matt K. Turner  \
# 20001                            Jonathan W.C. Mills
# 20002             Michael Winterbottom, Thomas Hardy
# 20003                                     Bill Haney
# 20004                                    Neil LaBute
# ...                                              ...
# 23773                                            NaN
# 23774               Abdolreza Kahani, Hossein Mahkam
# 23775  Timo Kahilainen, Heikki Vihinen, Anttu Harlin
# 23776                                    Hiwa Abbasi
# 23777                                  Shahzad Nawaz
#
#                                                    Stars
# 20000    Kristin Chenoweth, Matthew Modine, Olesya Rulin  \
# 20001               Anne Heche, James Tupper, Ethan Peck
# 20002             Freida Pinto, Riz Ahmed, Mita Vashisht
# 20003         Nicole Beharie, Will Patton, Alfre Woodard
# 20004                           Stanley Tucci, Alice Eve
# ...                                                  ...
# 23773                 Drew Pearson, Saad Adam, Evan Adam
# 23774   Ahmad Mehranfar, Mehran Ahmadi, Nayereh Farahani
# 23775  Mikko Kivinen, Heikki Silvennoinen, Timo Kahil...
# 23776      Ruth Anianson, Arefeh Behbakht, Lina Burström
# 23777        Khalid Ahmed, Shafqat Cheema, Ehteshamuddin
#
#                                                Storyline  Rating  Rating Count
# 20000  When her family misses her jump roping competi...     6.2        7102.0
# 20001  A family&apos;s journey toward a better life i...     4.4        5184.0
# 20002  The story of the tragic relationship between t...     6.0        3278.0
# 20003  A single mother struggles to clear her name af...     6.9        2745.0
# 20004  A man surprises his former mistress by claimin...     5.8        2094.0
# ...                                                  ...     ...           ...
# 23773  Come with Saad as he visits Mount Druitt &amp;...     4.8        1531.0
# 23774  A man, who has some kind of a disease and eats...     6.8        1128.0
# 23775  A farce about blackmailing, a kidney transplan...     4.3        1398.0
# 23776  Said, the main character in the film Another P...     4.4        3333.0
# 23777  A group of friends are led by circumstances to...     7.7        1115.0
#
# [3778 rows x 10 columns]

# %%
df = df.dropna(subset=['Writer'])
test = test.dropna(subset=['Writer'])

# %%
import re
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stopwords_list = stopwords.words('english')

stopwords_list
stopwords_list.append(" ")
stopwords_list.append("")
stopwords_list.extend([chr(i) for i in range(ord('a'), ord('z') + 1)])

# Define a function to split text into words and remove specified words
def split_into_words_and_remove_stopwords(text, stopwords):
    # Split text using various separators (space, period, comma)
    words = re.split(r'\s+|[,\.:!?"&]', text)
    # Remove specified stopwords from the list
    words = [word.lower() for word in words if word.lower() not in stopwords]
    return words


# Apply the function to the "storyline" column
df['Storyline'] = df['Storyline'].apply(lambda x: split_into_words_and_remove_stopwords(x, stopwords_list))
df['Genre'] = df['Genre'].apply(lambda x: split_into_words_and_remove_stopwords(x, stopwords_list))
df['Stars'] = df['Stars'].apply(lambda x: x.split(','))
df['Writer'] = df['Writer'].apply(lambda x: x.split(','))

test['Stars'] = test['Stars'].apply(lambda x: x.split(','))

# Display the DataFrame
df['Certificate'].unique()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kingk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\2476211331.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Stars'] = test['Stars'].apply(lambda x: x.split(','))
# array(['PG-13', 'Unrated', 'PG', 'R', 'G', 'TV-14', 'TV-MA', 'TV-PG',
#        'NC-17', 'TV-Y7', 'TV-G', 'C13', 'Approved', 'C18', 'C16', 'C12',
#        'MA-17', 'TV-Y7-FV', 'AO', 'TV-Y', 'M', '(Banned)', 'C6', 'PG-12',
#        'GP', 'U', 'C7', 'C15'], dtype=object)

# %%
df_cat = df[['Certificate', 'Director', 'Rating', 'Rating Count', 'Genre']]
df_cat['Star'] = df['Stars'].apply(lambda x: x[0] if x else None)
test['Star'] = test['Stars'].apply(lambda x: x[0] if x else None)

all_genres = np.concatenate(df['Genre'].values)
unique_genres = pd.Series(all_genres).unique()

test['Genre'] = test['Genre'].apply(lambda x: split_into_words_and_remove_stopwords(x, stopwords_list))

for genre in unique_genres:
    df_cat[genre] = [genre in value for value in df_cat['Genre'].values]
    test[genre] = [genre in value for value in test['Genre'].values]

df_cat
# Out:
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat['Star'] = df['Stars'].apply(lambda x: x[0] if x else None)
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Star'] = test['Stars'].apply(lambda x: x[0] if x else None)
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Genre'] = test['Genre'].apply(lambda x: split_into_words_and_remove_stopwords(x, stopwords_list))
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[genre] = [genre in value for value in df_cat['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[genre] = [genre in value for value in df_cat['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat[genre] = [genre in value for value in df_cat['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
# C:\Users\kingk\AppData\Local\Temp\ipykernel_12028\3105285134.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[genre] = [genre in value for value in test['Genre'].values]
#       Certificate                        Director  Rating  Rating Count
# 0           PG-13               Christopher Nolan     9.0     2800000.0  \
# 1           PG-13                   Peter Jackson     9.0     1900000.0
# 2         Unrated                    Jabbar Patel     8.9        2700.0
# 3           PG-13                   Peter Jackson     8.8     2000000.0
# 4           PG-13                   Peter Jackson     8.8     1700000.0
# ...           ...                             ...     ...           ...
# 19995          PG                      Marc Forby     6.1        1887.0
# 19996           R                   Andrew Drazek     3.6        1008.0
# 19997       PG-12  Borja Soler, Rodrigo Sorogoyen     6.9        4851.0
# 19998           R                    Biyi Bandele     6.1        2109.0
# 19999           R                  Samuel Fischer     6.1        2714.0
#
#                              Genre                    Star  action  crime
# 0           [action, crime, drama]          Christian Bale    True   True  \
# 1       [action, adventure, drama]             Elijah Wood    True  False
# 2             [biography, history]               Mammootty   False  False
# 3       [action, adventure, drama]             Elijah Wood    True  False
# 4       [action, adventure, drama]             Elijah Wood    True  False
# ...                            ...                     ...     ...    ...
# 19995  [biography, drama, history]  Q&apos;orianka Kilcher   False  False
# 19996                     [comedy]         Laura Silverman   False  False
# 19997             [drama, romance]          Javier Pereira   False  False
# 19998             [drama, romance]        Chiwetel Ejiofor   False  False
# 19999     [action, drama, history]        Jonathan Bennett    True  False
#
#        drama  adventure  ...  mystery  sci-fi  music    war  romance  musical
# 0       True      False  ...    False   False  False  False    False    False  \
# 1       True       True  ...    False   False  False  False    False    False
# 2      False      False  ...    False   False  False  False    False    False
# 3       True       True  ...    False   False  False  False    False    False
# 4       True       True  ...    False   False  False  False    False    False
# ...      ...        ...  ...      ...     ...    ...    ...      ...      ...
# 19995   True      False  ...    False   False  False  False    False    False
# 19996  False      False  ...    False   False  False  False    False    False
# 19997   True      False  ...    False   False  False  False     True    False
# 19998   True      False  ...    False   False  False  False     True    False
# 19999   True      False  ...    False   False  False  False    False    False
#
#        sport  horror   news  western
# 0      False   False  False    False
# 1      False   False  False    False
# 2      False   False  False    False
# 3      False   False  False    False
# 4      False   False  False    False
# ...      ...     ...    ...      ...
# 19995  False   False  False    False
# 19996  False   False  False    False
# 19997  False   False  False    False
# 19998  False   False  False    False
# 19999  False   False  False    False
#
# [19795 rows x 28 columns]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.utils import shuffle
from imblearn.pipeline import make_pipeline
from imblearn.over_sampling import RandomOverSampler

# Xử lý đặc trưng trước khi tách ra thành tập huấn luyện và tập kiểm tra
numeric_features = ['Rating', 'Rating Count']
categorical_features = ['Certificate', 'Director', 'Star']

numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

ans = []

for genre in unique_genres:
    X = df_cat[['Certificate', 'Director', 'Star', 'Rating', 'Rating Count']]
    y = df_cat[genre]

    X_preprocessed = preprocessor.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

    model = make_pipeline(
        RandomOverSampler(random_state=42),
        LogisticRegression()
    )

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    print(genre)

    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print(f'F1-score: {f1}')
    
    print("")
    if (accuracy >= 0.69 and recall >= 0.5):
        ans.append([genre, accuracy, recall])
# Out:
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# action
# Accuracy: 0.8259661530689568
# Precision: 0.5771349862258953
# Recall: 0.5230961298377028
# F1-score: 0.5487884741322855
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# crime
# Accuracy: 0.7837837837837838
# Precision: 0.3465045592705167
# Recall: 0.3486238532110092
# F1-score: 0.3475609756097561
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# drama
# Accuracy: 0.6976509219499873
# Precision: 0.7225969645868465
# Recall: 0.7607634265423879
# F1-score: 0.7411891891891892
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# adventure
# Accuracy: 0.8648648648648649
# Precision: 0.4207650273224044
# Recall: 0.515625
# F1-score: 0.46339017051153464
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# biography
# Accuracy: 0.8949229603435211
# Precision: 0.24642857142857144
# Recall: 0.2518248175182482
# F1-score: 0.24909747292418774
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# history
# Accuracy: 0.9312957817630715
# Precision: 0.16666666666666666
# Recall: 0.15476190476190477
# F1-score: 0.16049382716049385
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# thriller
# Accuracy: 0.776963879767618
# Precision: 0.3665223665223665
# Recall: 0.3638968481375358
# F1-score: 0.36520488856937455
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# animation
# Accuracy: 0.9520080828492044
# Precision: 0.47058823529411764
# Recall: 0.6857142857142857
# F1-score: 0.558139534883721
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# family
# Accuracy: 0.931800959838343
# Precision: 0.29432624113475175
# Recall: 0.538961038961039
# F1-score: 0.38073394495412843
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# documentary
# Accuracy: 0.9517554938115685
# Precision: 0.4662576687116564
# Recall: 0.4222222222222222
# F1-score: 0.44314868804664714
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# comedy
# Accuracy: 0.7264460722404648
# Precision: 0.6290463692038495
# Recall: 0.5217706821480407
# F1-score: 0.57040856802856
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# fantasy
# Accuracy: 0.9194240969941905
# Precision: 0.14948453608247422
# Recall: 0.15846994535519127
# F1-score: 0.15384615384615385
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# mystery
# Accuracy: 0.859307906036878
# Precision: 0.22193211488250653
# Recall: 0.24709302325581395
# F1-score: 0.233837689133425
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# sci-fi
# Accuracy: 0.9214448092952766
# Precision: 0.18719211822660098
# Recall: 0.20652173913043478
# F1-score: 0.19638242894056848
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# music
# Accuracy: 0.9484718363223036
# Precision: 0.05504587155963303
# Recall: 0.056074766355140186
# F1-score: 0.05555555555555555
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# war
# Accuracy: 0.963122000505178
# Precision: 0.0273972602739726
# Recall: 0.025974025974025976
# F1-score: 0.02666666666666667
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# romance
# Accuracy: 0.7918666329881283
# Precision: 0.3711507293354943
# Recall: 0.3443609022556391
# F1-score: 0.3572542901716068
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# musical
# Accuracy: 0.9823187673654964
# Precision: 0.14285714285714285
# Recall: 0.1111111111111111
# F1-score: 0.125
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# sport
# Accuracy: 0.9653953018439
# Precision: 0.11764705882352941
# Recall: 0.09411764705882353
# F1-score: 0.10457516339869281
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# horror
# Accuracy: 0.8678959333164941
# Precision: 0.45955882352941174
# Recall: 0.5219206680584552
# F1-score: 0.4887585532746823
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# news
# Accuracy: 0.9994948219247285
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
#
# western
# Accuracy: 0.992422328870927
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
# C:\Users\kingk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
